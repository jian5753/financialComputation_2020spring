# %%
import EXB1

# %%
S0 = 50
K = 55
T = 0.5
r = 0.1
q = 0.03

# %% [markdown]
# # Bisection B-S Euro

# %%
targetPrice = 2.5
IV = EXB1.IvEuBsBisection(targetPrice, S0, K, T, r, q, 0.0000001)
# Out:
# 5.697491788061786
# 2.2515515299848055
# 3.9628828493233286
# 3.1016270028158672
# 2.674624604065489
# 2.462499292990021
# 2.5684285707201724
# 2.5154289766219655
# 2.488955185116751
# 2.5021898702518364
# 2.495571971707637
# 2.4988807824026082
# 2.500535291734913
# 2.4997080284141973
# 2.500121657911727
# 2.499914842622154
# 2.500018250131756
# 2.499966546343156
# 2.499992398229004
# 2.5000053241782645
# 2.4999988612031068
# 2.5000020926905506
# 2.500000476946795
# 2.499999669074942

# %%
IV * 100
# Out:
# 26.83931291103363

# %% [markdown]
# # Bisection Tree Euro

# %%
targetPrice = 2.5
IV = EXB1.IvBiTreeBisection(targetPrice, S0, K, T, r, q, 100, 0.0000001, True)
# Out:
# 5.710472670078504
# 2.2557519758409583
# 3.9655687136901143
# 3.100628773432184
# 2.6817090475490812
# 2.469758419458564
# 2.5759694253377377
# 2.5229253058050727
# 2.4963575323837475
# 2.50964529528007
# 2.503002387986073
# 2.4996802043661415
# 2.501341357140877
# 2.5005107960047894
# 2.5000955039995474
# 2.4998878551365085
# 2.499991679806436
# 2.500043591962591
# 2.5000176358993973
# 2.5000046578566404
# 2.49999816883245
# 2.5000014133447674
# 2.4999997910886784
# 2.500000602216755
# 2.5000001966527257

# %%
IV * 100
# Out:
# 26.78457647562027

# %% [markdown]
# # Bisection Tree Amrc

# %%
targetPrice = 6.5
IV = EXB1.IvBiTreeBisection(targetPrice, S0, K, T, r, q, 100, 0.0000001, False, True)
# Out:
# 9.113559554692442
# 5.830617661267454
# 7.411130665881304
# 6.594870073444315
# 6.206960642873056
# 6.400140663490861
# 6.497288960804456
# 6.546014348979933
# 6.521647531042451
# 6.509470733684848
# 6.503380070470413
# 6.500334169712537
# 6.4988110766664615
# 6.499572635089749
# 6.499953405375321
# 6.500143788287355
# 6.500048597017243
# 6.500001001242765
# 6.4999772033206815
# 6.499989102284611
# 6.499995051764424
# 6.499998026503775
# 6.49999951387332
# 6.5000002575580655
# 6.4999998857156704

# %%
IV * 100
# Out:
# 30.490486323833466
